# %%
import pandas as pd

# %%
# hosd patients
df = pd.read_csv('MIMIC-IV (3.1)/hosp/patients.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#    subject_id gender  anchor_age  anchor_year anchor_year_group         dod
# 0    10000032      F          52         2180       2014 - 2016  2180-09-09
# 1    10000048      F          23         2126       2008 - 2010         NaN
# 2    10000058      F          33         2168       2020 - 2022         NaN
# 3    10000068      F          19         2160       2008 - 2010         NaN
# 4    10000084      M          72         2160       2017 - 2019  2161-02-13

# %%
print(f" Total Patients = {df['subject_id'].nunique()}")
# Out:
#  Total Patients = 364627

# %%
print(f"Average Age {df["anchor_age"].min()}")
# Out:
# Average Age 18

# %%
df_micro_events = pd.read_csv('MIMIC-IV (3.1)/hosp/microbiologyevents.csv', low_memory=False)
df_micro_events
# Out:
#          microevent_id  subject_id     hadm_id  micro_specimen_id  \
# 0                    1    10000032         NaN            1304715
# 1                    2    10000032         NaN            3342526
# 2                    3    10000032         NaN            3910370
# 3                    4    10000032         NaN            5401234
# 4                    5    10000032         NaN            6287540
# ...                ...         ...         ...                ...
# 3988219        3988220    19999987  23865745.0            4998105
# 3988220        3988221    19999987  23865745.0             945091
# 3988221        3988222    19999987  23865745.0            1483778
# 3988222        3988223    19999987  23865745.0            9584280
# 3988223        3988224    19999987  23865745.0            9074855
#
#         order_provider_id            chartdate            charttime  \
# 0                  P69FQC  2180-03-23 00:00:00  2180-03-23 11:51:00
# ...

# %%
print(f'Total Patients = {df_micro_events['subject_id'].nunique()}')
# Out:
# Total Patients = 222313
